# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
allocine= []
for i in range(1, 40):
    url = f'https://www.allocine.fr/film/fichefilm-178014/critiques/spectateurs/?page={i}'
    response = requests.get(url)
    soup = BeautifulSoup(response.text,'html.parser')

    links=soup.findAll('div', {"class": "hred review-card cf"})
    
    for link in links: 
        new_com = {}
        new_com['note'] = link.find("span", {'class':"stareval-note"}).text.replace(',', '.')
        new_com['commentaire'] = link.find("div", {'class':"content-txt review-card-content"}).text
        allocine.append(new_com)

# %%
df=pd.DataFrame(allocine, columns=['note', 'commentaire'])
df.head()
# Out:
#   note                                        commentaire
# 0  4.5  \nEnfin de retour sur Pandora treize ans après...
# 1  5.0  \nBon je vais pas faire trop long, car clairem...
# 2  4.0  \nAvatar : La Voie de L'eau c'est une première...
# 3  3.5  \nIl serait difficile de mettre moins de 3 éto...
# 4  3.5  \nVisuellement hallucinatoire de beauté et de ...

# %%
df.to_csv('avatar2_web_scrapping', index=False, encoding='utf-8')

# %%
empdata = pd.read_csv('C:\PythonWork\\allociné-web-scrapping\\avatar2_web_scrapping', index_col=False, delimiter = ',')
empdata.head()
# Out:
#    note                                        commentaire
# 0   4.5  \nEnfin de retour sur Pandora treize ans après...
# 1   5.0  \nBon je vais pas faire trop long, car clairem...
# 2   4.0  \nAvatar : La Voie de L'eau c'est une première...
# 3   3.5  \nIl serait difficile de mettre moins de 3 éto...
# 4   3.5  \nVisuellement hallucinatoire de beauté et de ...

# %%
import mysql.connector as mysql
from mysql.connector import Error

user = 'root'
password = 'example'
host = 'localhost'
port = '3308'

try:
    conn = mysql.connect(host=host, port=port, user=user,  
                        password=password)
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("CREATE DATABASE allociné")
        print("Database is created")
except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# Error while connecting to MySQL 1007 (HY000): Can't create database 'allociné'; database exists

# %%
user = 'root'
password = 'example'
host = 'localhost'
port = '3308'
database = 'allociné'

try:
    conn = mysql.connect(host=host, port=port, user=user, password=password, database=database)
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute('DROP TABLE IF EXISTS avatar2;')
        print('Creating table....')
        cursor.execute("CREATE TABLE avatar2(note float, commentaire varchar(10000));")
        print("Table is created....")
        for i,row in empdata.iterrows():
            sql = "INSERT INTO avatar2 VALUES (%s,%s)"
            cursor.execute(sql, tuple(row))
            print("Record inserted")
            conn.commit()
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('allociné',)
# Creating table....
# Table is created....
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %%
sql = "SELECT AVG(note) FROM allociné.avatar2 ORDER BY note"
cursor.execute(sql)
result = cursor.fetchall()
print(result)
# Out:
# [(3.8026315789473686,)]
